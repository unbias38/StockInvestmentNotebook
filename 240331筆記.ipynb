# %% [markdown]
# ### 【[周末影音解盤](https://www.facebook.com/kevinyang20180801/videos/1091224385486341/)】短線盤整，市場觀望
# 加權指數創高之後，短線進入盤整，櫃買指數持續維持小箱型整理，緊接著有春假連休，市場觀望氣氛濃厚，整體盤勢和操作策略應該如何調整？
# 完整內容請參考影音解盤~
# https://www.facebook.com/kevinyang20180801/videos/1091224385486341
# (聲音好像有點小，下周再調整。同學如果用電腦收看，可以調聲音大小，會比較方便。)

# %% [markdown]
# ![01.png](attachment:cd1688a2-4f28-477a-9e84-e967fd80b9f2.png)
# ![02.png](attachment:9c625141-3400-48aa-ae6c-5b2ee354fe6c.png)
# ![03.png](attachment:dcc83fcb-6f5e-4590-8ac0-dcd1a496a6aa.png)
# ![04.png](attachment:6a91b167-dd4d-4393-a316-a26818224f52.png)
# ![05.png](attachment:2fffd3dd-3f2f-4af5-85bb-2d477f1f53ee.png)
# ![06.png](attachment:b8d3767e-0d45-4acb-b504-1c3358da5c60.png)
# ![07.png](attachment:0e1987be-d4a0-4798-b30f-6d7d3442239b.png)
# ![08.png](attachment:c94a4c3d-bfbf-408a-8d34-c287a92c59c3.png)

# %% [markdown]
# ### 本日進度
# * 整理觀察股列表。本週新增：
#   - 神隆(1789)
#   - 六福(2705)
# * StockGPT程式碼確認：

# %%
import myutils

stock_gpt = myutils.StockGPT()
reply = stock_gpt.stock_gpt(stock_id="大盤")
print(reply)
# Out:
# ## 股市趨勢分析報告 - 2024 年 3 月
#
# ### 一、股價趨勢分析
# 根據最近的股價資訊，台灣大盤指數在 3 月 21 日至 3 月 29 日期間出現了一定的波動。收盤價從 20,199.09 點上升至 20,294.45 點，漲幅為 0.47%。每日報酬率的變動呈現波動性，其中 3 月 26 日收盤價下跌 0.33%，對應的漲跌價差為 -65.76 點。然而，整體趨勢仍然保持在漲升的狀態。
#
# ### 二、基本面分析
# 根據新聞資訊，投資者對於台股的情緒有所波動。投信於此期間買超台股累計金額達 1240 億元，並以創史上最大買超額的 600 億元買超單日作為反映。然而，投資人仍需留意投資戰線秉持波動不安、觀望持續。
#
# ### 三、新聞資訊與影響因素分析
# 新聞資訊指出,隨著高息 ETF 募集活動接連到來和進場布局，對台股盤勢持續產生一定影響。此外，投資人除了需關注地緣政治風險及美中關係轉變，還需密切留意 AI 產業的發展動態，以及高息 ETF 基金的換股等。
#
# ### 四、趨勢展望
# 基於以上分析，整體上看，台灣大盤指數在此期間呈現波動上升的趨勢。然而，投資者仍需謹慎應對，留意市場風險，關注新聞資訊的變化，以及投資環境的持續波動。
#
# 希望此份分析報告對您有所幫助。
