# %% [markdown]
# ### 【[K線捕手](https://www.facebook.com/kevinyang20180801)盤前快訊】美股走弱，留意賣壓
# 夜盤美國公布3月CPI比去年同期上揚3.5%，年增幅高於預期，抗通膨並未取得太大進展，市場認為聯準會的利率決策維持不變，道瓊指數終場下跌422點，跌破季線但季線暫時上揚，夜盤期指下跌135點。
# 昨天盤中曾提到其實歐、美、日股市，都已經短線轉弱，測試中期支撐，甚至有頭部雛形，甚至連上証、韓國也都反彈後轉弱，相較這些國際指數，台股能持續創高，可以算是一個神奇的存在。
# 要特別留意「個股再強，強不過大盤，大盤再強，強不過國際股市」，如果只是短線翻空，台股還是挺得住，但如果國際股市單日出現急跌，或跌破中期支撐，台股仍會有賣壓。尤其是暨特斯拉先前已經做頭下跌，蘋果和輝達目前也已經有中長期頭部雛形。
# 以夜盤期指跌幅表現，加上白天部分類股短線也有跟進轉強，今天指數有機會相對抗跌，還能維持漲多拉回測試支撐，而不是翻空，不過今天是個壓力測試的日子，務必要先把個股的支撐設定好，緊盯觀察個股變化。
# 複習昨天的觀點：空頭的低檔，要尋找機會，反過來，多頭的高檔，要留意風險。不論你如何樂觀，對市場有多大的期待，解盤時腦中永遠要將大腦思惟分割，一個大腦做多，一個大腦時時提醒風險，這樣當行情有反轉的變化，才能在第一時間反應，做出最客觀和精準的交易。 (歡迎分享，請載明出處K線捕手楊忠憲粉絲團)
# ![434832333_948162097317718_3944140436818909708_n.jpg](attachment:90ad06f2-0532-4f56-97cd-e1a2d0d39a37.jpg)

# %% [markdown]
# [美3月 CPI 年增幅高於預期 道瓊期指跌逾300點、美債殖利率升破4.5%](https://money.udn.com/money/story/5599/7890480?from=edn_newest_index&fbclid=IwAR06oCmx3Jsxw7zyrQl_i0u09mRtdWfAMDTCsR5fmwIBskatQzhzUbtULGE_aem_AQP-BL00IqfRFAiw3rxG21d_5PMBWXhJmH_XhQCg6KhH29UNUDnRf54Z62nxvSooISICvMeOBtkfR5FahED0y_ba)
# 美國3月消費者物價指數（CPI）比去年同期上揚3.5%，年增幅高於預期，顯示通膨依舊黏著，聯準會（Fed）的利率決策可能得繼續按兵不動，美股盤前三大期指均走跌，道瓊期指跌逾300點，美10年期公債殖利率升破4.5%，美元強彈，日圓跌破152關卡。市場如今預估，今年只會降息2碼。
#
# [投信轉賣超6.27億元 終結史上最大買超2,163億元紀錄](https://www.ctee.com.tw/news/20240410701296-430201?fbclid=IwAR38xEwEuWIdoNPDQTh5VRDR2P00fk9joLTkfgUU9V18VQIfr7TQinpuHoM_aem_AQPMNLqbvAx8nBNFPjQUaCMWMAFbbd2Ooit69ZrYIC_Snqir_QzFz30THOsxMaouf8oIF6LskjNKF_WtfQ9oQAIG)
# 投信今（10）日對台股集中市場轉為賣超6.27億元，終結過去連26日買超共2,163.01億元、史上最大買超金額的紀錄。投信扮演這波台股最重要多頭先鋒部隊，然而在今天加權指數最高衝上20,883點史上最高新紀錄下，終於逢高小幅調節，結束史上最大連買的紀錄。
#
# [美 CPI 年增3.5%幅度超預期 市場不再認為 Fed 會在6月降息](https://money.udn.com/money/story/5599/7890856?from=edn_maintab_index&fbclid=IwAR1i2H4BHYBnqUnBZuJXVFv2s_HjwXgANqkgevN7bR5oLZ7BzOpeSj0_i8E_aem_AQOuWaGeEc23ycCz7IpTAtnTi-AZ9V6CbsU3RHUmGFsqtoHnut06FVZ149SlCXpt3d70H5W4IqpRbDGNZFBQ2deL)
# 汽油和居住成本續升，使得美國3月消費者物價指數（CPI）年增3.5%，為連續第三個月高於預期。物價壓力持續之下，市場不再認為聯準會（Fed）會在6月降息，道瓊工業指數早盤大跌近400點，美國10年期公債殖利率也一度升破4.5%，為去年11月以來首見。
#
# [上市櫃3月營收重返3兆元 法人：優於預期且看好第2季淡季不淡](https://money.udn.com/money/story/5607/7890855?fbclid=IwAR2KU7EHt9oyUw6NgmM72XAMDM_POC3gJ8lOZkR9vMp0Z669yZ9iHwRV-p8_aem_AQPgKXV2o_SEO8dn11bQlrZsxJIreFDheUZPGuYm2wWztPmvduppJrEQTgkuoJCl37u9ukLLj7shutYCw0o0HGvw)
# 揮別2月工作天數減少影響，上市櫃公司3月營收表現優於預期，且3月營收創新高家數達57家，較2月的18家明顯增加，主要分布在生技、電子零組件、通信網路、半導體等。首季營收為9.78兆元，年增5.2%。
#
# [上市金控第1季大賺1,572億獲利翻倍 國泰金拿下三冠王](https://money.udn.com/money/story/5613/7890722?fbclid=IwAR1Wjwf0_q7uRNrxJvBqIpNWYyK_maZm9yLt6kqEmG6OijsZERZEKFnxfLw_aem_AQM6pb2Vok0qjhQaIf-lrwoar6GCYmHxxUYPkBIzgWL-w3_mHnhJjxPn2rJU7NOVcaNYub53tn2OTzQsU7rNURP-)
# 上市金控第1季大賺1,572億元翻倍成長，創下歷年同期次高紀錄，在美國升息到頂、資本市場暢旺與台美利差維持高檔下，金控旗下壽險、銀行、證券三路齊發，推升金控獲利躍進，金控雙雄國泰金（2882）、富邦金第1季均賺破300億元。
#
# [13檔營運月月升 躍外資新寵](https://www.ctee.com.tw/news/20240411700387-430201?fbclid=IwAR2aUSWZjKcVCxUauUwS2f5nh2XWBSh3Du2UIGGzd7PTCWgN7qb6HJ-hisA_aem_AQOmhJKdbVFUcqlDqW0fvj2OIC8tgt6ccVL9Vh5E2qREIQGhNOK--_otTIdRgk63wM94WAcLYNkhKBeQHR7hq4Et)
# 上市櫃企業3月營收出爐，統計今年以來營收連月走高股共有辛耘（3583）、台汽電（8926）、台塑化（6505）、美利達（9914）等13檔，且過去五個交易日獲得外資買超加持，倚靠業績與籌碼雙重加持，是市場短線焦點。
# 根據統計，今年以來營收逐月走高個股中，共有13檔在近五個交易日獲得外資買超逾百張加持，這些個股分別是：辛耘、台汽電、台塑化、上福、加捷生醫、全坤建、達發、台揚、乙盛-KY、捷流閥業、美利達、牧德、景岳。

# %% [markdown]
# #### 【K線捕手楊忠憲技術/籌碼概況說明】
# 以下不是我的持股，也不是推 薦，是網友主動提問，由於都是自己逐字整理，不是用電腦程式或是軟體機器人，但提問數量眾多，礙於時間跟版面，無法詳答和附圖，只能簡略回答個股現況。相關內容依照技術面和籌碼面做整理，僅為個人看法，完全開放無償分享，不做為任何交易之依據。任何投資都有風險，請審慎評估資金狀況、投資目標、風險承受程度及獨立交易的能力，並善設停利停損。
#
# 3673TPK-KY  中期底形轉強續漲，籌碼集中，留意滿足區和壓力區
# 2049上銀  短線轉弱，中期支撐有守，法人續買
# 2637慧洋  短線轉強，但反壓仍多，空間不明朗
# 3260威剛  突破中期箱型，可用旗型估算漲幅空間
# 00632R元大台灣50反1  短中長期偏空，不見支撐
# 3532台勝科  迷你底形續漲中，但空間不大
# 8064東捷  高檔盤整，籌碼不集中
# 2363矽統  短線偏多，但前高壓力尚未突破，中期還在大箱型區間
# 4958臻頂  短線續弱，測試中期支撐
# 5392能率  短線偏多，但前高壓力尚未突破，中期還在大箱型區間
# 3231緯創  高檔盤整，籌碼中性
# 3042晶技  短線盤整，籌碼中性
# 8121越峰  短線偏多，但離壓力區不遠
# 2884玉山金  中長期底形，短線盤整，尚未續漲
# 2409友達  短線偏多，籌碼集中，但反壓仍多
# 2330台積電  短中長期偏多，但位階高要會設移動支撐
#
# #### 【K線捕手楊忠憲技術/籌碼概況說明】
# 以下不是我的持股，也不是推 薦，是網友主動提問，由於都是自己逐字整理，不是用電腦程式或是軟體機器人，但提問數量眾多，礙於時間跟版面，無法詳答和附圖，只能簡略回答個股現況。相關內容依照技術面和籌碼面做整理，僅為個人看法，完全開放無償分享，不做為任何交易之依據。任何投資都有風險，請審慎評估資金狀況、投資目標、風險承受程度及獨立交易的能力，並善設停利停損。
#
# 5225東科-KY  短線轉弱，籌碼不集中
# 5340建榮  短線偏多，但前高壓力尚未突破，中期還在大箱型區間
# 3014聯陽  有迷你頭部雛形，籌碼不集中
# 5371中光電  短中強勢急漲，但位階高要會設移動支撐
# 6550北極星  短線轉強，但中期尚未轉強
# 3622洋華  短線轉弱，籌碼不集中，有迷你頭部
# 6691洋基  高檔狹幅盤整，籌碼中性，趨勢暫不明朗
# 3058立德  中期底形，短線盤整，尚未續漲
# 3289宜特  短線反彈遇壓，中期箱型區間
# 2548華固  短中強勢急漲，但位階高要會設移動支撐
# 3228金麗科  短線轉弱，有中期頭部雛形
# 2534宏盛  短中強勢急漲，但位階高要會設移動支撐
# 2472立隆電  暫時視為中期大箱型整理
# 6531愛普  中期頭部續跌中
#
# #### 【K線捕手楊忠憲技術/籌碼概況說明】
# 以下不是我的持股，也不是推 薦，是網友主動提問，由於都是自己逐字整理，不是用電腦程式或是軟體機器人，但提問數量眾多，礙於時間跟版面，無法詳答和附圖，只能簡略回答個股現況。相關內容依照技術面和籌碼面做整理，僅為個人看法，完全開放無償分享，不做為任何交易之依據。任何投資都有風險，請審慎評估資金狀況、投資目標、風險承受程度及獨立交易的能力，並善設停利停損。
#
# 2406 國碩  短線轉強，但尚未形成中期底形
# 3025星通  高檔盤整籌碼不集中，有頭部雛形
# 6176瑞儀  短線反彈，支撐暫時有守，籌碼中性
# 2492華新科  短線轉弱測試支撐，中期箱型整理
# 1609大亞  短線偏多，但空間不明朗
# 6770 力積電  跌深小反彈，但尚未轉強，短中長期偏空
# 4931新盛力  籌碼集中，有中期底形，但尚未完全轉強
# 4576大銀微系統  短線震盪，趨勢不明
# 2634漢翔  中期底形續漲中，但空間不大
# 4138 曜亞  短線轉弱，20日線暫時有守
# 3228金麗科  高檔盤整，籌碼不集中
# 6274台燿  短線測試支撐，位階高要會設移動支撐
# 2355敬鵬  中期大三角收斂整理
# 6163華電網  中小型三角收斂整理
# 2501 國建  短中長期強勢急漲，但位階高要會設移動支撐
# 3702大聯大  高檔箱型有頭部雛形
# 6811宏碁資訊  短線弱勢盤整，趨勢不明
# 8163達方  高檔盤整，籌碼不集中

# %% [markdown]
# 日本短線續弱，有中期頭部雛形：
# ![messageImage_1712793447135.jpg](attachment:0035df87-bc32-4092-8bc2-b974d9deff60.jpg)
#
# 期貨如預期的開低，5日線支撐有守：
# ![messageImage_1712796319042.jpg](attachment:dc4e351b-f0dd-4ddd-a83f-99d67d036a23.jpg)
#
# 加權指數跌幅收斂，表現相對穩定：
# ![messageImage_1712797251266.jpg](attachment:df50f492-8663-4cca-9598-245eb198b426.jpg)
#
# 櫃買表現也不錯：
# ![messageImage_1712797317042.jpg](attachment:19a94d16-8e8b-4206-b7c4-61ef6a4115fe.jpg)

# %% [markdown]
# 加權和櫃買跌勢都稍有擴大：
# ![340316.jpg](attachment:ba759841-e5a8-4fb0-806b-d7ecbe43f778.jpg)
# ![340317.jpg](attachment:8332be45-6117-4488-b322-295d61195efa.jpg)
#
# 今天空方力量較強的類股：
# ![messageImage_1712798999681.jpg](attachment:a6c98aab-dc47-4829-a737-d2e9a25b9c11.jpg)
#
# 今天空方壓力測試到這邊應該暫到一段落，,多方可以稍微喘息一下，不過還是要留意國際股市表現。
# ![messageImage_1712799607071.jpg](attachment:14f92ef4-2233-4369-bffe-25b217d3c9de.jpg)
#
# 如果昨天美股大跌，或是指數剛剛盤中小震盪一下，就覺得壓力很大，或是沒辦法專心上班，那有兩種可能，第一種，可能追高了某些股票，因此成本相對高，那是真的要盯很緊。第二種，表示持股的資金比重太高，應該調降一些。

# %% [markdown]
# 國泰金(2882)
# ![messageImage_1712797382028.jpg](attachment:b15d6aa2-2a88-4fd1-9932-a7c31ab5a8a9.jpg)
#
# 崧騰(3484)
# ![messageImage_1712801002221.jpg](attachment:4c986161-d9cc-4aed-965a-2bca457d66c7.jpg)
# ![messageImage_1712802712881.jpg](attachment:15c48731-0d0d-4789-89b3-e37f91d50315.jpg)

# %% [markdown]
# 期貨空單增加到萬口以上，第一天。
# ![340634.jpg](attachment:5daf7dcb-aa02-4246-b6d1-1dafa878775a.jpg)

# %% [markdown]
# ### 本日進度
# * 本日投資觀點：CPI再度高於預期，小型股風聲鶴唳
#   美國CPI高於預期及公債標售結果不佳，導致美10年債利率飆升18.2bp至4.54%，FedWatch押注6月降息的機率已剩不到20%，小型股首當其衝大幅下挫， 羅素2000收盤重摔2.52%收2,028。雖然AI巨頭輝達(+1.97%)、META(+0.57%)和台積電ADR(+0.53%)強勢撐盤，但仍不敵降息預期受挫的悲觀情緒，終場道瓊下跌1.09%至3,8461.5點，標普跌0.95%至5,160.6點，那指跌0.84%至16,170.4點。中國方面，萬科遭標普全球下調評級至BB+，萬科濟南總經理又遭警方帶走調查，加深房地產悲觀情緒；此外，惠譽將中國主權債評級展望下調至負面，導致滬深300下跌0.81%收3,504.7點，上證指數也跌0.7%至3,027點。
#   ![240411_1.png](attachment:0a808a47-31da-4050-83ea-61984bd2096e.png)
# * 神隆(1789)現持有1張，庫存現值28,050元(收盤價28.05元，跌0.65元)。規劃試單1張；估算目標價：31.00元，停損價(頸線)：27.75元。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 未實現損益 #####
stock_gains_losses = [['1789','神隆',1000,28340,28.34,28.05,27927,-413,-1.46]]
gains_losses_df = pd.DataFrame(stock_gains_losses,columns=['代碼', '股票名稱','即時庫存','付出成本','成本均價','現價','現值','損益試算','獲利率%'])
display(gains_losses_df)
# Out:
#      代碼 股票名稱  即時庫存   付出成本   成本均價     現價     現值  損益試算  獲利率%
# 0  1789   神隆  1000  28340  28.34  28.05  27927  -413 -1.46

# %%
##### 使用2023年3月16日到今日收盤(2024年4月11日)之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_1789_240411.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 設定頸線
neckline_start_date = '2023-08-10'
neckline_end_date = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
neckline_price = df_k_line.loc['2023-10-06']['Close']
breakout_date = '2024-04-08'

# 估算目標價
bottom_price_date = '2024-03-08'
bottom_price = df_k_line.loc[bottom_price_date]['Close']
target_price = (neckline_price - bottom_price) + neckline_price
print('頸線價格 ＝ {:.2f}元 ， 底部最低價格 ＝ {:.2f}元 ； 估算目標價 ＝ {:.2f}元'.format(neckline_price,bottom_price,target_price))
# Out:
# 頸線價格 ＝ 27.75元 ， 底部最低價格 ＝ 24.50元 ； 估算目標價 ＝ 31.00元

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
    [(bottom_price_date,bottom_price),(bottom_price_date,neckline_price)],
    [(neckline_end_date,neckline_price),(neckline_end_date,target_price)]
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.5,color='xkcd:maroon'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=1.0,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.5,color='xkcd:dark orange')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True,addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=(0.8,10,10), colors='xkcd:orange yellow', alpha=0.6), warn_too_much_data=1000)
mpf.plot(df_k_line,**kwargs)
